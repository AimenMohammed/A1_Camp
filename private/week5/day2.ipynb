# %%
# ar = [10 ,20 ,30 ,40,60,70,80]
# num = []
# lenth = len(ar)
# for x in range(lenth-2):
#     num.append(ar[x] + ar[x+1] + ar[x+2])
    
    
# print(max(num))

# %%
ar = [1000 ,20 ,30 ,40,60,70,80]
length = 3
nsum = sum(ar[:length])
result = nsum

for i in range(len(ar)-length):
    nsum = nsum - ar[i] + ar[i+length]
    print (nsum)
    if nsum > result:
        result = nsum
        
print (result)
# Out:
# 90
# 130
# 170
# 210
# 1050
