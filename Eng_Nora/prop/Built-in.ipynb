# %%
import math

print(math.sqrt(25))  # النتيجة: 5.0
print(math.pi)        # لطباعة قيمة "ط" أو "باي" (3.14...)
# Out:
# 5.0
# 3.141592653589793

# %%
import random

friends = ["أحمد", "سارة", "خالد"]
print(random.choice(friends))  # سيختار اسماً واحداً بشكل عشوائي في كل مرة
# Out:
# سارة

# %%
import datetime

now = datetime.datetime.now()
print(now)  # سيطبع السنة، الشهر، اليوم، والساعة الحالية
# Out:
# 2026-02-21 20:20:05.972688

# %%
import os

print(os.getcwd())  # يطبع مسار المجلد الحالي
# Out:
# c:\Users\HICOM\Documents\StudentPerformanceAnalyzerSystem\student_system

# %%
import json

data = {"name": "علي", "city": "الرياض"}
json_text = json.dumps(data)

print(json_text)  # النتيجة: '{"name": "\u0639\u0644\u064a", "city": "\u0627\u0644\u0631\u064a\u0627\u0636"}'
# Out:
# {"name": "\u0639\u0644\u064a", "city": "\u0627\u0644\u0631\u064a\u0627\u0636"}

# %%
import statistics

grades = [85, 90, 78, 92, 88]
print(statistics.mean(grades))  # النتيجة: 86.6 (المتوسط)

# %%
import re

text = "أهلاً بك في عالم بايثون"
if re.search("^أهلاً", text):
    print("النص يبدأ بكلمة ترحيب!")
# Out:
# النص يبدأ بكلمة ترحيب!

# %%
import time

print("سيظهر النص القادم بعد 3 ثوانٍ...")
time.sleep(3)
print("مرحباً مجدداً!")
# Out:
# سيظهر النص القادم بعد 3 ثوانٍ...
# مرحباً مجدداً!

# %%
import sys

print(sys.version)  # يطبع نسخة بايثون المثبتة حالياً
# Out:
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
from collections import Counter

letters = ["أ", "ب", "أ", "ج", "ب", "أ"]
counts = Counter(letters)
print(counts)  # النتيجة: تخبرك أن "أ" تكررت 3 مرات، و"ب" مرتين
# Out:
# Counter({'أ': 3, 'ب': 2, 'ج': 1})
